# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %% [markdown]
# ### Verificando se o codigo de ocorrencia é unico

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# ### Trocar o indice de uma tabela

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %% [markdown]
# ### Resentando o indice criado e voltando para o original

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ### Tirar os asteríticos da coluna ocorrencia_aerodromo

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
#
#    total_recomendacoes
# 0                    0

# %% [markdown]
# ### Trocar o valor de todas as colunas de uma linha

# %% [markdown]
# df.loc[1] = 20

# %% [markdown]
# ### Trocando o valor de toda a coluna

# %% [markdown]
# df.loc[:,'total_recomendacoes']

# %% [markdown]
# ### Criando uma coluna de backup

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                RJ
# 1                    0                PA
# ...

# %% [markdown]
# ### Criar uma condição para que quando o coluna ocorrencia_uf for 'SP' os dados da coluna 'ocorrencia_classificacao' da respectiva linha mude para 'GRAVE'

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'Grave'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    Grave            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 11                 40069                    Grave         SÃO PAULO
# 16                 39809                    Grave         SÃO PAULO
# 18                 39828                    Grave            SANTOS
# 26                 39847                    Grave          SOROCABA
# 27                 39768                    Grave          CAMPINAS
# ...                  ...                      ...               ...
# 5704               79739                    Grave         SÃO PAULO
# 5705               79705                    Grave          SOROCABA
# 5715               79718                    Grave         SÃO PAULO
# 5742               79800                    Grave         SÃO PAULO
# 5747               79804                    Grave          CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 11              SP                 SBMT     2010-01-10        14:50:00
# ...

# %% [raw]
# Limpando os dados da tabela
#
# ocorrencia_uf
# ***
#
# Ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
#
# ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 <NA>     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                RJ
# 1                    0                PA
# ...

# %% [markdown]
# ### Alterando todos os valores de todas as colunas para NA com Pandas

# %%
df.replace(['***', '###!', '####', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 <NA>     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                RJ
# 1                    0                PA
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# ocorrencia_uf_bkp              0
# dtype: int64

# %% [markdown]
# ### Alterar vizualização dos dados NA para o valor 10

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                   10     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                RJ
# 1                    0                PA
# ...

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            2
# ocorrencia_uf_bkp              0
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# ocorrencia_uf_bkp              0
# dtype: int64

# %% [markdown]
# ### Excluindo uma coluna

# %%
df.drop(['ocorrencia_uf_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0              40211                INCIDENTE      RIO DE JANEIRO
# 1              40349                INCIDENTE               BELÉM
# 2              40351                INCIDENTE      RIO DE JANEIRO
# 3              39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4              40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 <NA>     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ### Excluindo uma coluna que contenha valor nulo ou <NA> que foi inserido anteriormente

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                 40211                INCIDENTE      RIO DE JANEIRO
# 1                 40349                INCIDENTE               BELÉM
# 2                 40351                INCIDENTE      RIO DE JANEIRO
# 3                 39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                 40324                INCIDENTE             PELOTAS
# ...                 ...                      ...                 ...
# 5747              79804                    Grave            CAMPINAS
# 5748              79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749              79802                INCIDENTE      RIO DE JANEIRO
# 5750              79756          INCIDENTE GRAVE           VICENTINA
# 5751              79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                 40211                INCIDENTE      RIO DE JANEIRO
# 1                 40349                INCIDENTE               BELÉM
# 2                 40351                INCIDENTE      RIO DE JANEIRO
# 3                 39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                 40324                INCIDENTE             PELOTAS
# ...                 ...                      ...                 ...
# 5747              79804                    Grave            CAMPINAS
# 5748              79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749              79802                INCIDENTE      RIO DE JANEIRO
# 5750              79756          INCIDENTE GRAVE           VICENTINA
# 5751              79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# ### Verificar arquivos duplicados

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...
